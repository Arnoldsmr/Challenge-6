# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 628

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}units={units}&appid={weather_api_key}&q="
# remember: you need to work towards that querly url 
# and dont forget the documentation or resources to find out parameters 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() # individual request for city weather based on city url query

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"] 
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date
                         })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | rio grande
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | gafanha da nazare
# Processing Record 5 of Set 1 | ust-nera
# Processing Record 6 of Set 1 | sidareja
# Processing Record 7 of Set 1 | port shepstone
# Processing Record 8 of Set 1 | mandalgovi
# Processing Record 9 of Set 1 | whitehorse
# Processing Record 10 of Set 1 | broome
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | lagunas
# Processing Record 13 of Set 1 | westport
# Processing Record 14 of Set 1 | bilibino
# Processing Record 15 of Set 1 | turpan
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | mullovka
# Processing Record 18 of Set 1 | west island
# Processing Record 19 of Set 1 | ta`u
# Processing Record 20 of Set 1 | wailua homesteads
# Processing Record 21 of Set 1 | geraldton
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | puerto natales
# Processing Record 24 of Set 1 | north shore
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | cabedelo
# Processing Record 27 of Set 1 | lielvarde
# Processing Record 28 of Set 1 | grytviken
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | thakhek
# Processing Record 33 of Set 1 | edinburgh of the seven seas
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | salinopolis
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | sitka
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | broken hill
# Processing Record 40 of Set 1 | sao tome
# Processing Record 41 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 42 of Set 1 | nsanje
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | kuraymah
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | andalusia
# Processing Record 47 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 48 of Set 1 | tolanaro
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | ouadda
# Processing Record 0 of Set 2 | maralal
# Processing Record 1 of Set 2 | hayma'
# City not found. Skipping...
# Processing Record 2 of Set 2 | hirtshals
# Processing Record 3 of Set 2 | east honolulu
# City not found. Skipping...
# Processing Record 4 of Set 2 | talen
# Processing Record 5 of Set 2 | saint-pierre
# Processing Record 6 of Set 2 | adamstown
# Processing Record 7 of Set 2 | kapuskasing
# Processing Record 8 of Set 2 | lihue
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | nemuro
# Processing Record 11 of Set 2 | blackmans bay
# Processing Record 12 of Set 2 | pekanbaru
# Processing Record 13 of Set 2 | afaahiti
# Processing Record 14 of Set 2 | kalmunai
# Processing Record 15 of Set 2 | belogorsk
# Processing Record 16 of Set 2 | jhanjharpur
# Processing Record 17 of Set 2 | hasaki
# Processing Record 18 of Set 2 | shiqian
# Processing Record 19 of Set 2 | hawaiian paradise park
# Processing Record 20 of Set 2 | klyuchi
# Processing Record 21 of Set 2 | polyarnyy
# Processing Record 22 of Set 2 | road town
# Processing Record 23 of Set 2 | arar
# Processing Record 24 of Set 2 | cole harbour
# Processing Record 25 of Set 2 | vernon
# Processing Record 26 of Set 2 | zaozersk
# Processing Record 27 of Set 2 | yeniseysk
# Processing Record 28 of Set 2 | margaret river
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | phan thiet
# Processing Record 31 of Set 2 | olonkinbyen
# Processing Record 32 of Set 2 | badger
# Processing Record 33 of Set 2 | noumea
# Processing Record 34 of Set 2 | barcelos
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | vorgashor
# Processing Record 37 of Set 2 | ugoofaaru
# Processing Record 38 of Set 2 | aswan
# Processing Record 39 of Set 2 | tanjung selor
# City not found. Skipping...
# Processing Record 40 of Set 2 | dudinka
# Processing Record 41 of Set 2 | iskateley
# Processing Record 42 of Set 2 | igarka
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | norilsk
# Processing Record 45 of Set 2 | mabini
# Processing Record 46 of Set 2 | thunder bay
# Processing Record 47 of Set 2 | goundam
# Processing Record 48 of Set 2 | lazaro cardenas
# Processing Record 49 of Set 2 | praia da vitoria
# Processing Record 0 of Set 3 | bandarbeyla
# Processing Record 1 of Set 3 | raduzhnyy
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | ubari
# Processing Record 4 of Set 3 | vilyuchinsk
# Processing Record 5 of Set 3 | colonia
# Processing Record 6 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 7 of Set 3 | komsomolets
# Processing Record 8 of Set 3 | krasnovishersk
# Processing Record 9 of Set 3 | laizhou
# Processing Record 10 of Set 3 | choibalsan
# Processing Record 11 of Set 3 | kilindoni
# Processing Record 12 of Set 3 | sakiet sidi youssef
# Processing Record 13 of Set 3 | bubaque
# Processing Record 14 of Set 3 | constantia
# Processing Record 15 of Set 3 | sola
# Processing Record 16 of Set 3 | happy valley-goose bay
# Processing Record 17 of Set 3 | papatowai
# Processing Record 18 of Set 3 | nogliki
# Processing Record 19 of Set 3 | svay rieng
# Processing Record 20 of Set 3 | comalapa
# Processing Record 21 of Set 3 | pariaman
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | arraial do cabo
# Processing Record 24 of Set 3 | agadez
# Processing Record 25 of Set 3 | lincheng
# Processing Record 26 of Set 3 | tralee
# Processing Record 27 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 28 of Set 3 | puerto deseado
# Processing Record 29 of Set 3 | morondava
# Processing Record 30 of Set 3 | chicoana
# Processing Record 31 of Set 3 | adh dhayd
# Processing Record 32 of Set 3 | agustin codazzi
# Processing Record 33 of Set 3 | mount isa
# Processing Record 34 of Set 3 | utrik
# Processing Record 35 of Set 3 | katsuura
# Processing Record 36 of Set 3 | winona
# Processing Record 37 of Set 3 | ulanhot
# Processing Record 38 of Set 3 | trashi yangtse
# Processing Record 39 of Set 3 | pamandzi
# Processing Record 40 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 41 of Set 3 | tshabong
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | braganca paulista
# Processing Record 44 of Set 3 | espargos
# City not found. Skipping...
# Processing Record 45 of Set 3 | hirara
# Processing Record 46 of Set 3 | cannonvale
# Processing Record 47 of Set 3 | betioky
# Processing Record 48 of Set 3 | ilulissat
# Processing Record 49 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 0 of Set 4 | capinota
# Processing Record 1 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 2 of Set 4 | el alto
# Processing Record 3 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 4 | port mathurin
# Processing Record 5 of Set 4 | puerto baquerizo moreno
# Processing Record 6 of Set 4 | ponta delgada
# Processing Record 7 of Set 4 | tuscania
# Processing Record 8 of Set 4 | princeville
# Processing Record 9 of Set 4 | la sarre
# Processing Record 10 of Set 4 | adrar
# Processing Record 11 of Set 4 | fale old settlement
# Processing Record 12 of Set 4 | coahuayana de hidalgo
# Processing Record 13 of Set 4 | fortaleza
# Processing Record 14 of Set 4 | tura
# Processing Record 15 of Set 4 | swakopmund
# Processing Record 16 of Set 4 | novyy urgal
# Processing Record 17 of Set 4 | alice
# Processing Record 18 of Set 4 | mugia
# Processing Record 19 of Set 4 | tazovsky
# Processing Record 20 of Set 4 | manokwari
# Processing Record 21 of Set 4 | kargasok
# Processing Record 22 of Set 4 | talnakh
# Processing Record 23 of Set 4 | flying fish cove
# Processing Record 24 of Set 4 | yung shue wan
# Processing Record 25 of Set 4 | tazacorte
# Processing Record 26 of Set 4 | delijan
# Processing Record 27 of Set 4 | arteche
# Processing Record 28 of Set 4 | jilib
# Processing Record 29 of Set 4 | mahajanga
# Processing Record 30 of Set 4 | chonchi
# Processing Record 31 of Set 4 | grand-bassam
# Processing Record 32 of Set 4 | kruisfontein
# Processing Record 33 of Set 4 | sur
# Processing Record 34 of Set 4 | punta arenas
# Processing Record 35 of Set 4 | ilagan
# Processing Record 36 of Set 4 | inhambane
# Processing Record 37 of Set 4 | weaverham
# Processing Record 38 of Set 4 | cabo san lucas
# Processing Record 39 of Set 4 | alice springs
# Processing Record 40 of Set 4 | ati
# Processing Record 41 of Set 4 | abengourou
# Processing Record 42 of Set 4 | juan griego
# Processing Record 43 of Set 4 | dwarka
# Processing Record 44 of Set 4 | forster
# Processing Record 45 of Set 4 | satupa'itea
# City not found. Skipping...
# Processing Record 46 of Set 4 | vila do maio
# Processing Record 47 of Set 4 | mont-dore
# Processing Record 48 of Set 4 | oodweyne
# Processing Record 49 of Set 4 | machali
# Processing Record 0 of Set 5 | selfoss
# Processing Record 1 of Set 5 | walvis bay
# Processing Record 2 of Set 5 | stanley
# Processing Record 3 of Set 5 | sinjar
# Processing Record 4 of Set 5 | east london
# Processing Record 5 of Set 5 | ikwiriri
# Processing Record 6 of Set 5 | pemba
# Processing Record 7 of Set 5 | seferihisar
# Processing Record 8 of Set 5 | prineville
# Processing Record 9 of Set 5 | pangody
# Processing Record 10 of Set 5 | neiafu
# Processing Record 11 of Set 5 | thaton
# Processing Record 12 of Set 5 | oranjemund
# Processing Record 13 of Set 5 | kaitong
# Processing Record 14 of Set 5 | bandar-e lengeh
# Processing Record 15 of Set 5 | fallon
# Processing Record 16 of Set 5 | rukban
# City not found. Skipping...
# Processing Record 17 of Set 5 | invercargill
# Processing Record 18 of Set 5 | tyukalinsk
# Processing Record 19 of Set 5 | salym
# Processing Record 20 of Set 5 | kavieng
# Processing Record 21 of Set 5 | timmins
# Processing Record 22 of Set 5 | isla vista
# Processing Record 23 of Set 5 | lensk
# Processing Record 24 of Set 5 | san luis de la loma
# Processing Record 25 of Set 5 | conceicao das alagoas
# Processing Record 26 of Set 5 | neryungri
# Processing Record 27 of Set 5 | mount gambier
# Processing Record 28 of Set 5 | kingaroy
# Processing Record 29 of Set 5 | lluta
# Processing Record 30 of Set 5 | lubartow
# Processing Record 31 of Set 5 | sao joao dos inhamuns
# Processing Record 32 of Set 5 | yeppoon
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | isafjordur
# Processing Record 35 of Set 5 | jorpeland
# Processing Record 36 of Set 5 | susuman
# Processing Record 37 of Set 5 | balcarce
# Processing Record 38 of Set 5 | tsiombe
# Processing Record 39 of Set 5 | labrador city
# Processing Record 40 of Set 5 | taiynsha
# Processing Record 41 of Set 5 | cascais
# Processing Record 42 of Set 5 | kingston
# Processing Record 43 of Set 5 | verkhnevilyuysk
# Processing Record 44 of Set 5 | floro
# Processing Record 45 of Set 5 | minas de marcona
# Processing Record 46 of Set 5 | micheweni
# Processing Record 47 of Set 5 | kapa'a
# Processing Record 48 of Set 5 | brookings
# Processing Record 49 of Set 5 | dakhla
# Processing Record 0 of Set 6 | fes
# Processing Record 1 of Set 6 | ola
# Processing Record 2 of Set 6 | chibougamau
# Processing Record 3 of Set 6 | gueoul
# City not found. Skipping...
# Processing Record 4 of Set 6 | jiwani
# Processing Record 5 of Set 6 | qaqortoq
# Processing Record 6 of Set 6 | kafue
# Processing Record 7 of Set 6 | queenstown
# Processing Record 8 of Set 6 | barakani
# Processing Record 9 of Set 6 | nar'yan-mar
# Processing Record 10 of Set 6 | toscolano maderno
# Processing Record 11 of Set 6 | launceston
# Processing Record 12 of Set 6 | durbuy
# Processing Record 13 of Set 6 | aasiaat
# Processing Record 14 of Set 6 | haiku-pauwela
# Processing Record 15 of Set 6 | nouadhibou
# Processing Record 16 of Set 6 | okahao
# Processing Record 17 of Set 6 | bikenibeu village
# Processing Record 18 of Set 6 | nurabad
# Processing Record 19 of Set 6 | taksimo
# Processing Record 20 of Set 6 | fuyu
# Processing Record 21 of Set 6 | mokhsogollokh
# Processing Record 22 of Set 6 | saratamata
# City not found. Skipping...
# Processing Record 23 of Set 6 | rudnyy
# Processing Record 24 of Set 6 | agat village
# Processing Record 25 of Set 6 | changde
# Processing Record 26 of Set 6 | hamilton
# Processing Record 27 of Set 6 | alofi
# Processing Record 28 of Set 6 | fort bragg
# Processing Record 29 of Set 6 | mozhga
# Processing Record 30 of Set 6 | jever
# Processing Record 31 of Set 6 | popondetta
# Processing Record 32 of Set 6 | new norfolk
# Processing Record 33 of Set 6 | banganapalle
# Processing Record 34 of Set 6 | aykhal
# Processing Record 35 of Set 6 | yabelo
# Processing Record 36 of Set 6 | cockburn town
# Processing Record 37 of Set 6 | shubarshi
# Processing Record 38 of Set 6 | kavaratti
# Processing Record 39 of Set 6 | pudozh
# Processing Record 40 of Set 6 | quibdo
# Processing Record 41 of Set 6 | palma del rio
# Processing Record 42 of Set 6 | hoeryong
# Processing Record 43 of Set 6 | hue
# Processing Record 44 of Set 6 | newman
# Processing Record 45 of Set 6 | san antonio de pale
# Processing Record 46 of Set 6 | malvan
# Processing Record 47 of Set 6 | melekeok village
# Processing Record 48 of Set 6 | beau vallon
# Processing Record 49 of Set 6 | san rafael
# Processing Record 0 of Set 7 | la villa del rosario
# Processing Record 1 of Set 7 | tongouson
# Processing Record 2 of Set 7 | yanykurgan
# Processing Record 3 of Set 7 | coquimbo
# Processing Record 4 of Set 7 | forio
# Processing Record 5 of Set 7 | anadyr
# Processing Record 6 of Set 7 | zavitinsk
# Processing Record 7 of Set 7 | kirakira
# Processing Record 8 of Set 7 | udachny
# Processing Record 9 of Set 7 | howard springs
# Processing Record 10 of Set 7 | san ignacio
# Processing Record 11 of Set 7 | condoto
# Processing Record 12 of Set 7 | sarakhs
# Processing Record 13 of Set 7 | vanimo
# Processing Record 14 of Set 7 | ihosy
# Processing Record 15 of Set 7 | freetown
# Processing Record 16 of Set 7 | aldinga beach
# Processing Record 17 of Set 7 | argenton-sur-creuse
# Processing Record 18 of Set 7 | oriximina
# Processing Record 19 of Set 7 | nazret
# Processing Record 20 of Set 7 | enewetak
# Processing Record 21 of Set 7 | meadow lake
# Processing Record 22 of Set 7 | san patricio
# Processing Record 23 of Set 7 | cadale
# Processing Record 24 of Set 7 | vanino
# Processing Record 25 of Set 7 | kuta
# Processing Record 26 of Set 7 | lagos
# Processing Record 27 of Set 7 | micoud
# Processing Record 28 of Set 7 | sabang
# Processing Record 29 of Set 7 | paracuru
# Processing Record 30 of Set 7 | sal rei
# Processing Record 31 of Set 7 | el bauga
# Processing Record 32 of Set 7 | brisas de zicatela
# Processing Record 33 of Set 7 | marsa alam
# Processing Record 34 of Set 7 | ulsteinvik
# Processing Record 35 of Set 7 | dien bien phu
# Processing Record 36 of Set 7 | meizhou
# Processing Record 37 of Set 7 | hithadhoo
# Processing Record 38 of Set 7 | posto fiscal rolim de moura
# Processing Record 39 of Set 7 | ambatofinandrahana
# Processing Record 40 of Set 7 | g'uzor
# Processing Record 41 of Set 7 | zaragoza
# Processing Record 42 of Set 7 | dauphin
# Processing Record 43 of Set 7 | sandnessjoen
# Processing Record 44 of Set 7 | nuuk
# Processing Record 45 of Set 7 | sinabang
# Processing Record 46 of Set 7 | vallenar
# Processing Record 47 of Set 7 | tomatlan
# Processing Record 48 of Set 7 | castillos
# Processing Record 49 of Set 7 | chapaev
# Processing Record 0 of Set 8 | berriane
# Processing Record 1 of Set 8 | horsham
# Processing Record 2 of Set 8 | icmeler
# Processing Record 3 of Set 8 | recani
# Processing Record 4 of Set 8 | kabo
# Processing Record 5 of Set 8 | abu al matamir
# Processing Record 6 of Set 8 | lago da pedra
# Processing Record 7 of Set 8 | bayganin
# Processing Record 8 of Set 8 | corner brook
# Processing Record 9 of Set 8 | ziro
# Processing Record 10 of Set 8 | berezovyy
# Processing Record 11 of Set 8 | opuwo
# Processing Record 12 of Set 8 | las heras
# Processing Record 13 of Set 8 | sanming
# Processing Record 14 of Set 8 | alaior
# Processing Record 15 of Set 8 | rabo de peixe
# Processing Record 16 of Set 8 | prince rupert
# Processing Record 17 of Set 8 | rongelap
# Processing Record 18 of Set 8 | svetlogorsk
# Processing Record 19 of Set 8 | skovorodino
# Processing Record 20 of Set 8 | qashyr
# Processing Record 21 of Set 8 | kununurra
# Processing Record 22 of Set 8 | antofagasta
# Processing Record 23 of Set 8 | kurnool
# Processing Record 24 of Set 8 | kotabumi
# Processing Record 25 of Set 8 | luang prabang
# Processing Record 26 of Set 8 | oliva de la frontera
# Processing Record 27 of Set 8 | buabidi
# City not found. Skipping...
# Processing Record 28 of Set 8 | as sulayyil
# Processing Record 29 of Set 8 | palikir - national government center
# Processing Record 30 of Set 8 | dunedin
# Processing Record 31 of Set 8 | troitsko-pechorsk
# Processing Record 32 of Set 8 | ancud
# Processing Record 33 of Set 8 | gadzhiyevo
# Processing Record 34 of Set 8 | birao
# Processing Record 35 of Set 8 | pathein
# Processing Record 36 of Set 8 | loudun
# Processing Record 37 of Set 8 | vorkuta
# Processing Record 38 of Set 8 | bafoulabe
# Processing Record 39 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 8 | atafu village
# Processing Record 41 of Set 8 | laojunmiao
# Processing Record 42 of Set 8 | keflavik
# Processing Record 43 of Set 8 | la passe
# Processing Record 44 of Set 8 | st. john's
# Processing Record 45 of Set 8 | ormara
# Processing Record 46 of Set 8 | dinajpur
# Processing Record 47 of Set 8 | ayr
# Processing Record 48 of Set 8 | chone
# Processing Record 49 of Set 8 | darwin
# Processing Record 0 of Set 9 | we
# City not found. Skipping...
# Processing Record 1 of Set 9 | arawa
# Processing Record 2 of Set 9 | tbeng meanchey
# Processing Record 3 of Set 9 | berbera
# Processing Record 4 of Set 9 | leirvik
# Processing Record 5 of Set 9 | cardenas
# Processing Record 6 of Set 9 | coxen hole
# Processing Record 7 of Set 9 | zouerate
# Processing Record 8 of Set 9 | winejok
# City not found. Skipping...
# Processing Record 9 of Set 9 | yorkton
# Processing Record 10 of Set 9 | tabou
# Processing Record 11 of Set 9 | severo-yeniseyskiy
# Processing Record 12 of Set 9 | neuburg an der donau
# Processing Record 13 of Set 9 | alo
# Processing Record 14 of Set 9 | san andres
# Processing Record 15 of Set 9 | siocon
# Processing Record 16 of Set 9 | lethem
# Processing Record 17 of Set 9 | concepcion
# Processing Record 18 of Set 9 | naukot
# Processing Record 19 of Set 9 | manakara
# Processing Record 20 of Set 9 | trashigang
# Processing Record 21 of Set 9 | olot
# Processing Record 22 of Set 9 | hastings
# Processing Record 23 of Set 9 | newtown trim
# Processing Record 24 of Set 9 | pangkalanbuun
# Processing Record 25 of Set 9 | pran buri
# Processing Record 26 of Set 9 | nahiyat ash shinafiyah
# Processing Record 27 of Set 9 | uturoa
# Processing Record 28 of Set 9 | baardheere
# Processing Record 29 of Set 9 | weligama
# Processing Record 30 of Set 9 | nova olinda do norte
# Processing Record 31 of Set 9 | muroto-misakicho
# Processing Record 32 of Set 9 | namibe
# Processing Record 33 of Set 9 | pohang
# Processing Record 34 of Set 9 | bairnsdale
# Processing Record 35 of Set 9 | at taj
# Processing Record 36 of Set 9 | la ronge
# Processing Record 37 of Set 9 | kiunga
# Processing Record 38 of Set 9 | tatsunocho-tominaga
# Processing Record 39 of Set 9 | katima mulilo
# Processing Record 40 of Set 9 | mejit
# Processing Record 41 of Set 9 | kristiansund
# Processing Record 42 of Set 9 | tofol
# Processing Record 43 of Set 9 | fernley
# Processing Record 44 of Set 9 | vetluga
# Processing Record 45 of Set 9 | peniche
# Processing Record 46 of Set 9 | cheongsong gun
# Processing Record 47 of Set 9 | guanica
# Processing Record 48 of Set 9 | san carlos
# Processing Record 49 of Set 9 | new river
# Processing Record 0 of Set 10 | grand falls-windsor
# Processing Record 1 of Set 10 | santa elena de uairen
# Processing Record 2 of Set 10 | zeya
# Processing Record 3 of Set 10 | bovalino
# Processing Record 4 of Set 10 | lompoc
# Processing Record 5 of Set 10 | las khorey
# Processing Record 6 of Set 10 | saldanha
# Processing Record 7 of Set 10 | yarmouth
# Processing Record 8 of Set 10 | greenville
# Processing Record 9 of Set 10 | ambodifotatra
# Processing Record 10 of Set 10 | amos
# Processing Record 11 of Set 10 | roja
# Processing Record 12 of Set 10 | irtyshsk
# Processing Record 13 of Set 10 | nguigmi
# Processing Record 14 of Set 10 | champerico
# Processing Record 15 of Set 10 | ust'-uda
# Processing Record 16 of Set 10 | ganshui
# Processing Record 17 of Set 10 | grants
# Processing Record 18 of Set 10 | mbandaka
# Processing Record 19 of Set 10 | vidyayevo
# Processing Record 20 of Set 10 | kailua-kona
# Processing Record 21 of Set 10 | zelenoborskiy
# Processing Record 22 of Set 10 | palu
# Processing Record 23 of Set 10 | illizi
# Processing Record 24 of Set 10 | antalaha
# Processing Record 25 of Set 10 | tainan
# Processing Record 26 of Set 10 | flin flon
# Processing Record 27 of Set 10 | armacao de buzios
# Processing Record 28 of Set 10 | odessa
# Processing Record 29 of Set 10 | port alfred
# Processing Record 30 of Set 10 | pangai
# Processing Record 31 of Set 10 | revelstoke
# Processing Record 32 of Set 10 | mussoorie
# Processing Record 33 of Set 10 | nuku'alofa
# Processing Record 34 of Set 10 | kaseda-shirakame
# Processing Record 35 of Set 10 | mukah
# City not found. Skipping...
# Processing Record 36 of Set 10 | anajatuba
# Processing Record 37 of Set 10 | barra de santo antonio
# Processing Record 38 of Set 10 | taro
# Processing Record 39 of Set 10 | bandon
# Processing Record 40 of Set 10 | dashitou
# Processing Record 41 of Set 10 | jackson
# Processing Record 42 of Set 10 | acarau
# Processing Record 43 of Set 10 | berdigestyakh
# Processing Record 44 of Set 10 | ar ruways
# Processing Record 45 of Set 10 | weno
# Processing Record 46 of Set 10 | santana
# Processing Record 47 of Set 10 | yura
# Processing Record 48 of Set 10 | shenjiamen
# Processing Record 49 of Set 10 | santa cruz verapaz
# Processing Record 0 of Set 11 | naranjal
# Processing Record 1 of Set 11 | mahina
# Processing Record 2 of Set 11 | manglaur
# Processing Record 3 of Set 11 | itacare
# Processing Record 4 of Set 11 | ostersund
# Processing Record 5 of Set 11 | butte
# Processing Record 6 of Set 11 | cidreira
# Processing Record 7 of Set 11 | gangtok
# Processing Record 8 of Set 11 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 9 of Set 11 | zyryanskoye
# Processing Record 10 of Set 11 | portland
# Processing Record 11 of Set 11 | gebeit
# Processing Record 12 of Set 11 | praya
# Processing Record 13 of Set 11 | akureyri
# Processing Record 14 of Set 11 | lublin
# Processing Record 15 of Set 11 | howrah
# Processing Record 16 of Set 11 | san jose del guaviare
# Processing Record 17 of Set 11 | smirnykh
# Processing Record 18 of Set 11 | byron bay
# Processing Record 19 of Set 11 | naracoorte
# Processing Record 20 of Set 11 | nema
# Processing Record 21 of Set 11 | arkhipo-osipovka
# Processing Record 22 of Set 11 | mikhaylovskoye
# Processing Record 23 of Set 11 | ashland
# Processing Record 24 of Set 11 | cruzeiro do sul
# Processing Record 25 of Set 11 | celendin
# Processing Record 26 of Set 11 | holualoa
# Processing Record 27 of Set 11 | el granada
# Processing Record 28 of Set 11 | al ghayzah
# Processing Record 29 of Set 11 | halden
# Processing Record 30 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 31 of Set 11 | sao pedro do piaui
# Processing Record 32 of Set 11 | deqen
# Processing Record 33 of Set 11 | pryor creek
# Processing Record 34 of Set 11 | jiujiang
# Processing Record 35 of Set 11 | kerikeri
# Processing Record 36 of Set 11 | gamonal
# Processing Record 37 of Set 11 | belyy yar
# Processing Record 38 of Set 11 | chertsey
# Processing Record 39 of Set 11 | siwa oasis
# Processing Record 40 of Set 11 | port blair
# Processing Record 41 of Set 11 | daru
# Processing Record 42 of Set 11 | saurimo
# Processing Record 43 of Set 11 | aur
# Processing Record 44 of Set 11 | heiligenhafen
# Processing Record 45 of Set 11 | mata-utu
# Processing Record 46 of Set 11 | gulf shores
# Processing Record 47 of Set 11 | reggane
# Processing Record 48 of Set 11 | paoua
# Processing Record 49 of Set 11 | sydney
# Processing Record 0 of Set 12 | varazze
# Processing Record 1 of Set 12 | sao gabriel da cachoeira
# Processing Record 2 of Set 12 | richards bay
# Processing Record 3 of Set 12 | vadso
# Processing Record 4 of Set 12 | ocean city
# Processing Record 5 of Set 12 | nasiriyah
# Processing Record 6 of Set 12 | wad medani
# Processing Record 7 of Set 12 | eyl
# Processing Record 8 of Set 12 | kupiskis
# Processing Record 9 of Set 12 | hoxtolgay
# City not found. Skipping...
# Processing Record 10 of Set 12 | starkville
# Processing Record 11 of Set 12 | oualidia
# City not found. Skipping...
# Processing Record 12 of Set 12 | edson
# Processing Record 13 of Set 12 | zangguy
# City not found. Skipping...
# Processing Record 14 of Set 12 | fonte boa
# Processing Record 15 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 16 of Set 12 | pea ridge
# Processing Record 17 of Set 12 | lahat
# Processing Record 18 of Set 12 | santa cruz del norte
# Processing Record 19 of Set 12 | mitu
# Processing Record 20 of Set 12 | pistoia
# Processing Record 21 of Set 12 | nabire
# Processing Record 22 of Set 12 | balqash
# Processing Record 23 of Set 12 | greymouth
# Processing Record 24 of Set 12 | altayskoye
# Processing Record 25 of Set 12 | vila franca do campo
# Processing Record 26 of Set 12 | miranda do corvo
# Processing Record 27 of Set 12 | auki
# Processing Record 28 of Set 12 | viedma
# Processing Record 29 of Set 12 | necochea
# Processing Record 30 of Set 12 | yagry
# City not found. Skipping...
# Processing Record 31 of Set 12 | chita
# Processing Record 32 of Set 12 | santa vitoria do palmar
# Processing Record 33 of Set 12 | wewak
# Processing Record 34 of Set 12 | kidal
# Processing Record 35 of Set 12 | mataram
# Processing Record 36 of Set 12 | cairns city
# City not found. Skipping...
# Processing Record 37 of Set 12 | kupang
# Processing Record 38 of Set 12 | sisimiut
# Processing Record 39 of Set 12 | nanlong
# Processing Record 40 of Set 12 | luanda
# Processing Record 41 of Set 12 | karyes
# Processing Record 42 of Set 12 | kolonia town
# Processing Record 43 of Set 12 | harper
# Processing Record 44 of Set 12 | naberera
# Processing Record 45 of Set 12 | rikaze
# Processing Record 46 of Set 12 | ar rutbah
# Processing Record 47 of Set 12 | madalena
# Processing Record 48 of Set 12 | ribeira brava
# Processing Record 49 of Set 12 | haisyn
# Processing Record 0 of Set 13 | lame
# Processing Record 1 of Set 13 | as suwayq
# Processing Record 2 of Set 13 | pariang
# City not found. Skipping...
# Processing Record 3 of Set 13 | fairfield
# Processing Record 4 of Set 13 | san pedro
# Processing Record 5 of Set 13 | phultala
# Processing Record 6 of Set 13 | quatre cocos
# Processing Record 7 of Set 13 | kyzyl-mazhalyk
# Processing Record 8 of Set 13 | pacific grove
# Processing Record 9 of Set 13 | touba
# Processing Record 10 of Set 13 | kasongo-lunda
# Processing Record 11 of Set 13 | torres
# Processing Record 12 of Set 13 | oskarshamn
# Processing Record 13 of Set 13 | malpica
# Processing Record 14 of Set 13 | port douglas
# Processing Record 15 of Set 13 | valle de la pascua
# Processing Record 16 of Set 13 | khorinsk
# Processing Record 17 of Set 13 | bodo
# Processing Record 18 of Set 13 | mercedes
# Processing Record 19 of Set 13 | angaur state
# Processing Record 20 of Set 13 | lesosibirsk
# Processing Record 21 of Set 13 | saipan
# Processing Record 22 of Set 13 | laguna
# Processing Record 23 of Set 13 | lata
# Processing Record 24 of Set 13 | galveston
# Processing Record 25 of Set 13 | vigasio
# Processing Record 26 of Set 13 | iwon-up
# Processing Record 27 of Set 13 | bure
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          599
# Lat           599
# Lng           599
# Max Temp      599
# Humidity      599
# Cloudiness    599
# Wind Speed    599
# Country       599
# Date          599
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           waitangi -43.9535 -176.5597     11.01        77           4
# 1         rio grande -32.0350  -52.0986     15.53        96         100
# 2  port-aux-francais -49.3500   70.2167      3.67        89          96
# 3  gafanha da nazare  40.6362   -8.7134     16.45        93          65
# 4           ust-nera  64.5667  143.2000     21.80        40           5
#
#    Wind Speed Country        Date
# 0        0.89      NZ  1691639051
# 1        5.73      BR  1691639131
# 2       11.12      TF  1691639045
# 3        1.85      PT  1691639410
# 4        1.53      RU  1691638982

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 waitangi -43.9535 -176.5597     11.01        77           4
# 1               rio grande -32.0350  -52.0986     15.53        96         100
# 2        port-aux-francais -49.3500   70.2167      3.67        89          96
# 3        gafanha da nazare  40.6362   -8.7134     16.45        93          65
# 4                 ust-nera  64.5667  143.2000     21.80        40           5
#
#          Wind Speed Country        Date
# City_ID
# 0              0.89      NZ  1691639051
# 1              5.73      BR  1691639131
# 2             11.12      TF  1691639045
# 3              1.85      PT  1691639410
# 4              1.53      RU  1691638982

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lattitude = city_data_df["Lat"]
temperature = city_data_df["Max Temp"]
plt.scatter(lattitude,temperature,marker="o")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. temperature")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
humidity = city_data_df["Humidity"]
plt.scatter(lattitude,humidity,marker="o")
# Incorporate the other graph properties
plt.title("City Latitude Vs. Humidity (2022-20-18)")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloudiness = city_data_df["Cloudiness"]
plt.scatter(cloudiness,lattitude,marker="o" )
# Incorporate the other graph properties
plt.title("City Latitude Vs.Cloudiness (2022-20-18)")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig3.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind_speed = city_data_df["Wind Speed"]
plt.scatter(wind_speed,lattitude,marker="o")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Wind Speed (2022-20-18)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig4.png")
# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
